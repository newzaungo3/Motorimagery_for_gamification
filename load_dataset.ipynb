# %%
from braindecode.datasets.bbci import  BBCIDataset
cnt = BBCIDataset(filename='./dataset/hgd/data/train/1.mat', load_sensor_names=None).load()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-a2f72404cb4e> in <module>
#       1 from braindecode.datasets.bbci import  BBCIDataset
# ----> 2 cnt = BBCIDataset(filename='./dataset/hgd/data/train/1.mat', load_sensor_names=None).load()
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\braindecode\datasets\bbci.py in load(self)
#      36
#      37     def load(self):
# ---> 38         cnt = self._load_continuous_signal()
#      39         cnt = self._add_markers(cnt)
#      40         return cnt
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\braindecode\datasets\bbci.py in _load_continuous_signal(self)
#      41
#      42     def _load_continuous_signal(self):
# ---> 43         wanted_chan_inds, wanted_sensor_names = self._determine_sensors()
#      44         fs = self._determine_samplingrate()
#      45         with h5py.File(self.filename, "r") as h5file:
#
# ...

# %%
from scipy.io import loadmat
test_path = "dataset\\bci_dataset\\train\\A01TT.mat"
annots = loadmat("dataset\\bci_dataset\\train\\A01TT.mat")

# %%
annots
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNX86, Created on: Mon Nov 24 11:15:23 2008',
#  '__version__': '1.0',
#  '__globals__': [],
#  'classlabel': array([[4],
#         [3],
#         [2],
#         [1],
#         [1],
#         [2],
#         [3],
#         [4],
#         [2],
#         [3],
#         [1],
#         [1],
#         [1],
#         [4],
#         [2],
#         [2],
#         [1],
#         [1],
#         [3],
#         [1],
#         [2],
#         [4],
#         [4],
#         [3],
#         [1],
#         [4],
#         [4],
#         [2],
#         [4],
#         [4],
#         [2],
#         [1],
#         [2],
#         [3],
#         [3],
#         [3],
#         [4],
#         [3],
#         [1],
#         [4],
#         [2],
#         [3],
#         [2],
#         [3],
#         [4],
#         [2],
#         [3],
#         [1],
#         [1],
#         [1],
#         [4],
#         [2],
#         [1],
#         [3],
#         [1],
#         [3],
# ...
